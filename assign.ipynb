# %%
import pandas as pd
import numpy as np
import seaborn as sb

import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family']= 'Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus'] = False

import folium

# %%
df = pd.read_excel('assign/도로교통공단_전국_사망교통사고정보(2018).xlsx')
df
# Out:
#        발생년      발생년월일시  발생분 주야 요일  사망자수  사상자수  중상자수  경상자수  부상신고자수  ...  \
# 0     2018  2018021406   35  주  수     1     1     0     0       0  ...
# 1     2018  2018090205   23  야  일     1     1     0     0       0  ...
# 2     2018  2018121522   35  야  토     1     1     0     0       0  ...
# 3     2018  2018082311   30  주  목     1     1     0     0       0  ...
# 4     2018  2018071600   50  야  월     1     1     0     0       0  ...
# ...    ...         ...  ... .. ..   ...   ...   ...   ...     ...  ...
# 3652  2018  2018052103   55  야  월     1     1     0     0       0  ...
# 3653  2018  2018060808   43  주  금     1     1     0     0       0  ...
# 3654  2018  2018012010   15  주  토     1     1     0     0       0  ...
# 3655  2018  2018020321    5  야  토     1     1     0     0       0  ...
# 3656  2018  2018120310    5  주  월     1     2     0     1       0  ...
#
#      도로형태_대분류      도로형태 가해자_당사자종별_대분류 가해자_당사자종별 피해자_당사자종별_대분류 피해자_당사자종별  \
# ...

# %%
# 1. 서울에서 일어난 요일별
# 사망자수, 사상자수 를 출력하시요
seoul = df.groupby(['발생지시도', '요일'])
seoul.sum().loc['서울'][['사망자수', '사상자수']]
# Out:
#     사망자수  사상자수
# 요일
# 금     38    52
# 목     52    76
# 수     37    48
# 월     53    84
# 일     37    58
# 토     46    62
# 화     41    45

# %%
# 2. 서울 강북구 지역의 교통사고 위치를
# 지도로 표시하고 각마커에는 법규위반내용
# 을 표시하시요
df[['경도', '위도']]
map = folium.Map(location=[37.602829, 127.039508], zoom_start=12)

for i in range(len(df)):
    if df['발생지시군구'][i] == '성북구':
        mk = folium.Marker([df['위도'][i], df['경도'][i]], popup=df['법규위반'][i])
        mk.add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 3. 부산에서 발생한 총 사망자수를 구하시요
df[df['발생지시도']=='부산']['사망자수'].sum()
# Out:
# 123

# %%
# 4. 서울지역 월요일에 발생한 사상자수

df[(df['발생지시도']=='서울') & (df['요일'] == '월')][['발생지시도','사상자수', '사고유형','법규위반']]
# Out:
#      발생지시도  사상자수        사고유형         법규위반
# 4       서울     1          기타  안전운전 의무 불이행
# 6       서울     1         횡단중         신호위반
# 26      서울     1          기타  안전운전 의무 불이행
# 27      서울     1  길가장자리구역통행중  안전운전 의무 불이행
# 29      서울     1          기타  보행자 보호의무 위반
# 424     서울     3        측면충돌  안전운전 의무 불이행
# 427     서울     1         횡단중         신호위반
# 430     서울     1         횡단중         신호위반
# 431     서울     1          기타  안전운전 의무 불이행
# 437     서울     1         횡단중  보행자 보호의무 위반
# 443     서울     1       보도통행중  안전운전 의무 불이행
# 447     서울     2  길가장자리구역통행중  기타(운전자법규위반)
# 449     서울     1         횡단중  안전운전 의무 불이행
# 450     서울     1       공작물충돌  안전운전 의무 불이행
# 531     서울     9          추돌  안전운전 의무 불이행
# 900     서울     1         횡단중         신호위반
# 908     서울     1         횡단중         신호위반
# 915     서울     1         횡단중  안전운전 의무 불이행
# 919     서울     1  길가장자리구역통행중  안전운전 의무 불이행
# 924     서울     1          기타  안전운전 의무 불이행
# 928     서울     1       보도통행중  기타(운전자법규위반)
# ...

# %%
# 5. 횡단중 일어난 사고의 요일 
# 발생지시도, 법규위반, 피해자_당사자종별
# 을 구하시요

df[df['사고유형'] == '횡단중'][['요일', '법규위반', '피해자_당사자종별']]
# Out:
#      요일         법규위반 피해자_당사자종별
# 0     수  안전운전 의무 불이행       보행자
# 1     일  안전운전 의무 불이행       보행자
# 5     일  안전운전 의무 불이행       보행자
# 6     월         신호위반       보행자
# 7     금           과속       보행자
# ...  ..          ...       ...
# 3636  목  보행자 보호의무 위반       보행자
# 3639  금         신호위반       보행자
# 3643  토  안전운전 의무 불이행       보행자
# 3646  화  안전운전 의무 불이행       보행자
# 3647  월  안전운전 의무 불이행       보행자
#
# [791 rows x 3 columns]
