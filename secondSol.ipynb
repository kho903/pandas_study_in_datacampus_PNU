# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family']='Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus']=False

# %%
crimeDF= pd.read_csv('data/crime_in_Seoul.csv',
                     encoding='euc-kr', thousands = ',', index_col='관서명')
crimeDF
# Out:
#       살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  폭력 발생  폭력 검거
# 관서명
# 중부서       2      2      3      2    105     65   1395    477   1355   1170
# 종로서       3      3      6      5    115     98   1070    413   1278   1070
# 남대문서      1      0      6      4     65     46   1153    382    869    794
# 서대문서      2      2      5      4    154    124   1812    738   2056   1711
# 혜화서       3      2      5      4     96     63   1114    424   1015    861
# 용산서       5      5     14     14    194    173   1557    587   2050   1704
# 성북서       2      2      2      1     86     71    953    409   1194   1015
# 동대문서      5      5     13     13    173    146   1981    814   2548   2227
# 마포서       8      8     14     10    294    247   2555    813   2983   2519
# 영등포서     14     12     22     20    295    183   2964    978   3572   2961
# 성동서       4      4      9      8    126    119   1607    597   1612   1395
# ...

# %%
crimeDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   관서명     31 non-null     object
#  1   살인 발생   31 non-null     int64
#  2   살인 검거   31 non-null     int64
#  3   강도 발생   31 non-null     int64
#  4   강도 검거   31 non-null     int64
#  5   강간 발생   31 non-null     int64
#  6   강간 검거   31 non-null     int64
#  7   절도 발생   31 non-null     int64
#  8   절도 검거   31 non-null     int64
#  9   폭력 발생   31 non-null     int64
#  10  폭력 검거   31 non-null     int64
# dtypes: int64(10), object(1)
# memory usage: 2.8+ KB

# %%
# 1. 살인발생이 가장높은 관서명, 살인발생,살인검거를 출력하시요

# %%
num = crimeDF['살인 발생'].max()
crimeDF[crimeDF['살인 발생']==num][['살인 발생','살인 검거']]
# Out:
#       살인 발생  살인 검거
# 관서명
# 영등포서     14     12

# %%
# 2. 관서별 절도발생,절도검거에 대한 바차트를 그리시요
crimeDF.plot(y=['절도 발생','절도 검거'],kind='bar')
plt.show()

# %%
# 3. 절도검거율 컬럼을 추가 하시요.
crimeDF['절도 검거율(%)']=crimeDF['절도 검거']/crimeDF['절도 발생']*100
crimeDF
# Out:
#       살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  폭력 발생  폭력 검거  \
# 관서명
# 중부서       2      2      3      2    105     65   1395    477   1355   1170
# 종로서       3      3      6      5    115     98   1070    413   1278   1070
# 남대문서      1      0      6      4     65     46   1153    382    869    794
# 서대문서      2      2      5      4    154    124   1812    738   2056   1711
# 혜화서       3      2      5      4     96     63   1114    424   1015    861
# 용산서       5      5     14     14    194    173   1557    587   2050   1704
# 성북서       2      2      2      1     86     71    953    409   1194   1015
# 동대문서      5      5     13     13    173    146   1981    814   2548   2227
# 마포서       8      8     14     10    294    247   2555    813   2983   2519
# 영등포서     14     12     22     20    295    183   2964    978   3572   2961
# 성동서       4      4      9      8    126    119   1607    597   1612   1395
# ...

# %%
# 4. 살인발생, 강도발생 2개컬럼 평균값이
# 15건 이상이면 '범죄매우높음' 10건이상이면
# '범죄높음' 미만이면 '보통' 표시되는 '강력범죄정도'컬럼을 추가하시요
def fn( v):
    if v.mean() >=15:
        return '범죄매우높음'
    elif v.mean()>=10:
        return '범죄높음'
    else:
        return '보통'
    return v.mean()
crimeDF['강력범죄정도'] = crimeDF[['살인 발생','강도 발생']].apply(fn , axis= 1)

# %%
# 5. 관서명 마지막글자 '서'를 제외한 글자로 구성된
# '지역'컬럼을 추가하시요
# 예) 마포,영등포, 성동..., 수서
crimeDF['지역']=crimeDF.index.str[:-1]
crimeDF
# Out:
#       살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  폭력 발생  폭력 검거  \
# 관서명
# 중부서       2      2      3      2    105     65   1395    477   1355   1170
# 종로서       3      3      6      5    115     98   1070    413   1278   1070
# 남대문서      1      0      6      4     65     46   1153    382    869    794
# 서대문서      2      2      5      4    154    124   1812    738   2056   1711
# 혜화서       3      2      5      4     96     63   1114    424   1015    861
# 용산서       5      5     14     14    194    173   1557    587   2050   1704
# 성북서       2      2      2      1     86     71    953    409   1194   1015
# 동대문서      5      5     13     13    173    146   1981    814   2548   2227
# 마포서       8      8     14     10    294    247   2555    813   2983   2519
# 영등포서     14     12     22     20    295    183   2964    978   3572   2961
# 성동서       4      4      9      8    126    119   1607    597   1612   1395
# ...

# %%
# 6. 강도발생 탑5 관서명,강도발생, 강도검거를 출력하시요.
crimeDF[['강도 발생','강도 검거']].nlargest(5,'강도 발생')
# Out:
#       강도 발생  강도 검거
# 관서명
# 영등포서     22     20
# 강남서      15     12
# 구로서      15     11
# 용산서      14     14
# 마포서      14     10

# %%
# 7. 살인발생과, 강도발생, 절도발생의 상관관계를 구하고 heat map으로 표시하시요.
crime2 = crimeDF[['살인 발생','강도 발생','절도 발생']]
crime2.corr()
# Out:
#           살인 발생     강도 발생     절도 발생
# 살인 발생  1.000000  0.640281  0.662590
# 강도 발생  0.640281  1.000000  0.744599
# 절도 발생  0.662590  0.744599  1.000000

# %%
sb.heatmap(crime2.corr(),vmin=-1,vmax=1,annot=True,linewidth=0.5) #상관계수를 볼때는 -1과 1사이에서 볼수있음 #annot = True일때 계수 값을 볼수있음
plt.show()
